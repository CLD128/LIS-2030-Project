# %% [markdown]
# LIS 2030 Data and Information in Systems
#
# Team 11
#
# Carolyn Baker, Madeline Canales, Cassandra Dwyer, Michelle Watkins
#
# April 28, 2021

# %% [markdown]
# # <center> Policing, Drug Overdoses, and Median Age in Allegheny County from 2013 to 2015 <center>

# %% [markdown]
# In the United States, racial disparities in the criminal justice system and the disproportionate shooting of unarmed African Americans are reflective of systemic racism. Currently, national averages show that African Americans are disproportionately killed by police at rates of more than twice that of whites. The number of people killed by police from 2015 to today averages about 1,000 people every year.<sup>1</sup>
#
# The United States also faces an opioid crisis, with rates of death by accidental overdose seeing increased media attention. ADD MORE SENTENCES.
#
# Allegheny County collects and tracks data on median death rates over time. Media outlets, organizations, and non-governmental entities have created their own databases regarding deadly encounters with police by combining limited data provided by local, state, and federal governments as well as local media accounts. Data sets such as these will be utilized in providing data on police violence and overdose deaths. The focus of this project will be limited to data relating to males in Allegheny County.
#
# The project will explore fatal accidental overdoses data, the median age of death, and police brutality relating to demographics such as race and gender in Allegheny County from 2013 to 2015. Data analysis will aid in showing the rates of median age, location, and race of peoples both killed in police encounters and killed by drug overdose. The data collected can help to determine the racial makeup of victims of police violence and drug overdoses, both of which are important issues facing the United States today. Ultimately, the goal is to determine, in cases of fatal police counters and drug overdoses for men in Allegheny County during the years ranging from 2013 to 2015, if a disparity between African American and White men exists.
#
# The following topics will be addressed throughout the report: questions addressed in the project, a brief history of police-community relations and drug overdoses in Allegheny County and Pittsburgh, methodologies, data sources, the project and report, results, and insights gained from the project. In the sections that follow, an overview and narrative is provided based on data and data analysis to determine the number of fatal overdoses and police encounters relating to the median age of death and what it indicates about racial disparities.

# %% [markdown]
# ## Questions Addressed
#
# 1. How many individuals died in Allegheny County between 2013 and 2015 from drug overdose? How many individuals died in this same county and time frame from police encounters? What is the median age of death for each of these groups of people?
# 2. What was the overall median age at death of both white and black men in Allegheny County between 2013 and 2015, regardless of cause of death?
# 3. Between 2013 and 2015, what of the four demographic groups established (White men/Black men dying from police encounter/drug overdose) is closest to the median age at time of death in Allegheny County? What are the margins for each group?

# %% [markdown]
# ## A History of Policing and Overdoses in the City of Pittsburgh and Allegheny County
#
# To help conceptualize our project, a brief history of policing and race relations in Pittsburgh as well as overdoses Allegheny County is provided. It is important to recognize the historical background on these issues within Pittsburgh and Allegheny County. In the project, data analysis based on the questions addressed signifies the importance of geographic location and place. Additionally, background on policing, addiction, and overdoses helps to inform insights relating to policy decisions, inequality, stigma, and community activism.
#
# Articles featured in the *New Pittsburgh Courier*, a weekly African American newspaper, shows cases of police brutality demonstrating the police terror that residents faced as well as the lack of police accountability present in the City of Pittsburgh during the late twentieth century.
#
# In 1951, white patrolman Dan McTague brutally beat John Davis, who is pictured below, in an unprovoked incident at an after-hours club. Davis, a victim of police brutality, took blows to his back and stomach, suffered a possible skull fracture, lost teeth, sustained head injuries and abrasions to the head, cheek, eye and mouth and abdominal lacerations.
#
# A 1979 newspaper article, “Police Beating Blacks,” describes the beating of Robert Wade, a thirty-seven-year-old blind man, by Hill District officers. The two officers, Victor Muto and William Burke, beat up Wade because he looked like someone they were looking for and believed he had a weapon in his pocket. The officers involved were not reprimanded.
#
# Two more recent cases of police brutality includes…
#
# Police brutality was a common occurrence in African American neighborhoods in Pittsburgh. Police terror and police violence is a recurrent problem the African American community faces in the United States that exemplifies the destruction of communities and issues of segregation, discrimination, and racism.
#
# In Allegheny County, overdoses...

# %% [markdown]
# ![John Davis after being beaten by police officer Dan McTague, in his home at 1303 Wylie Avenue, Hill District (5).jpg](attachment:43ed615b-fe7b-4f3a-8a81-7b8759e703bc.jpg)
#
# John Davis after being beaten by police officer Dan McTague, in his home at 1303 Wylie Avenue, Hill District, August 1951.

# %% [markdown]
# ![March on MLK 1968 image1.jpeg](attachment:2ba0d48a-7c13-48d2-94a0-b068d0d64b7a.jpeg)
#
# March on MLK Jr. National Day of Mourning, 1968. The Charles Martin Photograph Collection, Archives Service Center, University of Pittsburgh.

# %% [markdown]
# ## Data Sources
#
# To address the questions, sources of data obtained include median age of death rates and death by overdose rates within Allegheny County as well as fatal encounters with police. Datasets pertaining to the median age of death and fatal accidental overdoses were obtained from the Western Pennsylvania Regional Data Center (WPRDC), an open data repository that aims to “make public information easier to find and use by hosting datasets” from institutions and organizations.<sup>2</sup> The WPRDC also maintains Allegheny County and the City of Pittsburgh’s open data portal. Data on fatal encounters with police was acquired from Mapping Police Violence, a research collaborative that collects data on police killings in the United States.
#
# Below sources and description of the data are provided:
#
# [Allegheny County Median Age at Death](https://data.wprdc.org/dataset/median-age-death): The dataset includes information about the median age of death for members located in Allegheny County by municipality. The data is based on the “deceased's residence at the time of death and not the location where the actual death occurred.”<sup>3</sup>  Median age is based on official death records released by the Pennsylvania Department of Health. Data is broken down by race and includes the count of deaths for Allegheny County Municipalities as well as neighborhoods within the City of Pittsburgh. The dataset was useful in determining the median age for both White and African American men between the years ranging from 2013 to 2015 in Allegheny County.
#
# [Mapping Police Violence](https://mappingpoliceviolence.org/): The data provides information on individuals who died during fatal counters with the police in the United States. The dataset was utilized to determine the race and median age of men within Allegheny County who were victims of police brutality. According to the Mapping Police Violence project, a police killing is defined as “a case where a person dies as a result of being shot, beaten, restrained, intentionally hit by a police vehicle, pepper sprayed, tasered, or otherwise harmed by police officers, whether on-duty or off-duty.”<sup>4</sup> (XXX).
#
# [Fatal Accidental Overdoses](https://data.wprdc.org/dataset/allegheny-county-fatal-accidental-overdoses): The dataset from the Western Pennsylvania Regional Data Center provides information such as the date, zip code of incident, zip code of residence, age, gender, and race of individuals who died by drug overdose in Allegheny County. In this case, the zip code of incident is considered the location of “where the Office of the Medical Examiner received the body and not necessarily where the overdose occurred.”<sup>5</sup> (WPRDC). The data will be useful in determining rates of drug overdoses for white and African American men in Allegheny County from the years ranging from 2013 to 2015.

# %% [markdown]
# ## Methodologies
#
# For the project, we utilized several Python libraries such as pandas, geopandas, matplotlib, and NumPy. These libraries were helpful in analyzing data to address our questions. Dataframes were useful in selecting the data needed to answer our questions.
#
# Additionally, Matplotlib was utilized to create data visualization maps to provide a visual aid showing the number of deaths for overdoses and police killings as well as to show the average age at the time of death from overdoses in Allegheny County. NumPy was used to create data visualizations for comparing the median ages regarding police encounters and overdoses for African American and White men.

# %% [markdown]
# ## The Project Report

# %% [markdown]
# # SECTION 1

# %% [markdown]
# To address how many individuals died in Allegheny County between 2013 and 2015 from drug overdoses and to determine the median age of death for each of these groups of people, the following Python libraries were imported.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats 

import matplotlib.pyplot as plt 
import geopandas as gpd

# %% [markdown]
# After importing the libraries into Python, the dataset containing fatal accidental overdoses was obtained from the Western Pennsylvania Regional Data Center. The dataset was then downloaded and uploaded to Jupyter Hub.

# %%
over_dose = pd.read_csv("files/fataloverdoses2.csv")
map_df = gpd.read_file('files/fataloverdoses2.csv')

# %% [markdown]
# The dataframe was narrowed to only include columns on age and case year.

# %%
ag = pd.read_csv("files/fataloverdoses2.csv", usecols = ['age','case_year'])
ag
#dataframe narrowed to age and case year
# Out:
#        age  case_year
# 0     31.0       2013
# 1     38.0       2013
# 2     51.0       2013
# 3     60.0       2013
# 4     58.0       2013
# ...    ...        ...
# 5336  55.0       2021
# 5337  40.0       2020
# 5338  44.0       2020
# 5339  52.0       2020
# 5340  30.0       2020
#
# [5341 rows x 2 columns]

# %% [markdown]
# Next, value counts was utilized to create a series containing the age and case year.

# %%
over_dose['age'].value_counts()
# Out:
# 51.0    166
# 34.0    158
# 52.0    153
# 30.0    153
# 29.0    151
#        ...
# 72.0      1
# 78.0      1
# 12.0      1
# 83.0      1
# 85.0      1
# Name: age, Length: 73, dtype: int64

# %%
over_dose['case_year'].value_counts()
# Out:
# 2017    739
# 2016    646
# 2020    543
# 2019    495
# 2018    432
# 2015    422
# 2014    306
# 2012    286
# 2013    269
# 2011    259
# 2008    231
# 2010    224
# 2007    223
# 2009    219
# 2021     47
# Name: case_year, dtype: int64

# %% [markdown]
# Next, loc was used to access the ages from 2013 to 2015

# %%
over_dose.loc["2013":"2015", "age"]
# Out:
# 2013    53.0
# 2014    35.0
# 2015    63.0
# Name: age, dtype: float64

# %%
fif = over_dose.loc[over_dose['case_year'] == 2015]

# %%
thir = over_dose.loc[over_dose['case_year'] == 2013]

# %%
fou = over_dose.loc[over_dose['case_year'] == 2014]

# %%
type(fou)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# A dataset was created containing the ages, sex, race, and case year of overdose victims.

# %%
years = (thir, fou, fif)

# %%
yea = [thir, fou, fif]

years = pd.concat(yea)
years
# Out:
#       death_date_and_time manner_of_death   age sex race case_dispo  \
# 0     2013-06-22T18:33:00        Accident  31.0   M    W         MO
# 1     2013-06-21T10:05:00        Accident  38.0   F    W         MO
# 2     2013-06-10T18:07:00        Accident  51.0   M    W         MO
# 3     2013-08-06T09:48:00        Accident  60.0   F    W         MO
# 4     2013-07-27T16:39:00       Accidents  58.0   F    W         MO
# ...                   ...             ...   ...  ..  ...        ...
# 5231  2015-01-10T10:40:00        Accident  45.0   F    B         MO
# 5232  2015-01-21T15:11:00        Accident  66.0   M    B         MO
# 5233  2015-01-20T11:06:00       Accidents  52.0   M    B         MO
# 5260  2015-01-12T13:05:00        Accident  49.0   M    W         MO
# 5261  2015-01-16T03:42:00        Accident  44.0   M    B         MO
#
#      combined_od1 combined_od2 combined_od3 combined_od4 combined_od5  \
# 0          HEROIN          NaN          NaN          NaN          NaN
# ...

# %% [markdown]
# From 2013 to 2015, the median age of death was 41.39 years.

# %%
years["age"].mean()
#median age of death from overdoses 2013 to 2015
# Out:
# 41.39317953861585

# %% [markdown]
# The number of individuals who died from overdoses in the years ranging from 2013 to 2015 was 997.

# %%
individ = years.index
incidents = len(individ)
incidents
#how many individuals died from overdoses between 2013 and 2015
# Out:
# 997

# %% [markdown]
# The dataframe was narrowed down to show the overdose deaths of White men.

# %%
raceW = years.loc[years['race'] == "W"]
raceMW = raceW.loc[raceW['sex'] == "M"]
raceMW
#dataframe narrowed down by white men
# Out:
#       death_date_and_time manner_of_death   age sex race case_dispo  \
# 0     2013-06-22T18:33:00        Accident  31.0   M    W         MO
# 2     2013-06-10T18:07:00        Accident  51.0   M    W         MO
# 69    2013-12-08T06:17:00        Accident  52.0   M    W         MO
# 70    2013-12-21T15:12:00        Accident  64.0   M    W         MO
# 103   2013-12-16T18:34:00        Accident  52.0   M    W         MO
# ...                   ...             ...   ...  ..  ...        ...
# 5099  2015-09-30T12:38:00        Accident  59.0   M    W         MO
# 5228  2015-01-01T18:24:00        Accident  28.0   M    W         MO
# 5229  2015-01-26T10:53:00        Accident  46.0   M    W         MO
# 5230  2015-01-19T12:15:00        Accident  26.0   M    W         MO
# 5260  2015-01-12T13:05:00        Accident  49.0   M    W         MO
#
#      combined_od1 combined_od2 combined_od3 combined_od4 combined_od5  \
# 0          HEROIN          NaN          NaN          NaN          NaN
# ...

# %% [markdown]
# Following, the dataframe was then narrowed down to show the overdose deaths of Black men.

# %%
raceB = years.loc[years['race'] == "B"]
raceMB = raceB.loc[raceB['sex'] == "M"]
raceMB
#dataframe narrowed by black men
# Out:
#       death_date_and_time manner_of_death   age sex race case_dispo  \
# 286   2013-04-23T10:55:00       Accidents  67.0   M    B         MO
# 287   2013-05-09T23:01:00        Accident  50.0   M    B         MO
# 409   2013-12-06T16:36:00        Accident  19.0   M    B         MO
# 821   2013-02-15T12:09:00        Accident  56.0   M    B         MO
# 1335  2013-12-01T09:48:00       Accidents  52.0   M    B         MO
# ...                   ...             ...   ...  ..  ...        ...
# 5142  2015-10-15T09:43:00        Accident  33.0   M    B         MO
# 5222  2015-01-06T17:33:00        Accident  45.0   M    B         MO
# 5232  2015-01-21T15:11:00        Accident  66.0   M    B         MO
# 5233  2015-01-20T11:06:00       Accidents  52.0   M    B         MO
# 5261  2015-01-16T03:42:00        Accident  44.0   M    B         MO
#
#      combined_od1 combined_od2 combined_od3 combined_od4 combined_od5  \
# 286        ALCOHO       HEROIN       HYDROO          NaN          NaN
# ...

# %% [markdown]
# The len function was utilized to determine the number of White and African American men who died by overdose from 2013 to 2015.

# %% [markdown]
# From 2013 to 2015, the number of deaths by overdose for White men was 591 and for Black men, the number of deaths was 98.

# %%
menW = len(raceMW)
menW
#number of white men who died via overdose from 2013-2015
# Out:
# 591

# %%
menB = len(raceMB)
menB
#number of black men who died via overdose from 2013-2015
# Out:
# 98

# %% [markdown]
# Next, a dataset was created in order to combine the deaths of White and Black men from 2013 to 2015.

# %%
raceWM13 = raceMW.loc[raceMW['case_year'] == 2013]
raceWM14 = raceMW.loc[raceMW['case_year'] == 2014]
raceWM15 = raceMW.loc[raceMW['case_year'] == 2015]
white_deaths = [raceWM13, raceWM14, raceWM15]
#white men deaths narrowed to each year
raceMB13 = raceMB.loc[raceMB['case_year'] == 2013]
raceMB14 = raceMB.loc[raceMB['case_year'] == 2014]
raceMB15 = raceMB.loc[raceMB['case_year'] == 2015]
black_deaths = [raceMB13, raceMB14, raceMB15]
#black men deaths narrowed to each year

races = [raceWM13, raceWM14, raceWM15, raceMB13, raceMB14, raceMB15]
races_2 = pd.concat(races)
#dataset combining deaths of white men and black men for year range

# %%
WD = pd.concat(white_deaths)
#dataframe of white male deaths during year range
BD = pd.concat(black_deaths)
#dataframe of black male deaths during year range

# %%
wdd = WD.set_index('case_year')
bdd = BD.set_index('case_year')
wbdd = [wdd, bdd]
full_chart = pd.concat(wbdd)

# %% [markdown]
# The dataframe displays the age of White and Black men who died by overdose in 2013 to 2015.

# %%
full_chart2 = full_chart[['age', 'race']]
full_chart2
# Out:
#             age race
# case_year
# 2013       31.0    W
# 2013       51.0    W
# 2013       52.0    W
# 2013       64.0    W
# 2013       52.0    W
# ...         ...  ...
# 2015       33.0    B
# 2015       45.0    B
# 2015       66.0    B
# 2015       52.0    B
# 2015       44.0    B
#
# [689 rows x 2 columns]

# %% [markdown]
# This dataframe displays the age of White men who died by overdose in 2013 to 2015.

# %%
full_chart2.loc[full_chart2["race"] == "W"]
# Out:
#             age race
# case_year
# 2013       31.0    W
# 2013       51.0    W
# 2013       52.0    W
# 2013       64.0    W
# 2013       52.0    W
# ...         ...  ...
# 2015       59.0    W
# 2015       28.0    W
# 2015       46.0    W
# 2015       26.0    W
# 2015       49.0    W
#
# [591 rows x 2 columns]

# %%
mask1 = years['race'] == 'W'
years[mask1].std()['age']
# Out:
# 12.078556598902166

# %%
mask2 = years['race'] =='B'
years[mask2].std()['age']
# Out:
# 12.199828724024053

# %% [markdown]
# The average age of overdose victims for Black men was 49.67 and for all White overdose victims, the average age was 40.05.

# %%
years[years['race'] == 'B'].mean()['age']
#average age of all black overdose vicitms
# Out:
# 49.666666666666664

# %%
years[years['race'] == 'W'].mean()['age']
#average age of all white overdose victims
# Out:
# 40.04778554778555

# %% [markdown]
# A dataframe was created to show the average age of overdose victims by race. As one can see, the avrage age of men who died by overdose for Black men was 49.28 and 39.77 for White men.

# %%
full_chart2.groupby('race').mean()
#average age of men at death by overdose split by race
# Out:
#            age
# race
# B     49.27551
# W     39.76819

# %% [markdown]
# The function mean was utilized to determine the average age of White and Black men who died for all of the years.

# %%
MW_age = raceMW["age"].mean()
#average age of white men who died for all years

# %%
MW = raceMB["age"].mean()
#average age of black men who died for all years

# %%
thir_count = thir.loc[thir['race'] == "W"]
fou_count = fou.loc[fou['race'] == "W"]
fif_count = fif.loc[fif['race'] == "W"]
#how many white people died each year

# %%
thir_countB = thir.loc[thir['race'] == "B"]
fou_countB = fou.loc[fou['race'] == "B"]
fif_countB = fif.loc[fif['race'] == "B"]
#how many black people died each year

# %%
thir_countWC = thir_count.loc[thir_count['sex'] == "M"]
fou_countWC = fou_count.loc[fou_count['sex'] == "M"]
fif_countWC = fif_count.loc[fif_count['sex'] == "M"]
#how manny white men died each year

# %%
thir_countBC = thir_countB.loc[thir_countB['sex'] == "M"]
fou_countBC = fou_countB.loc[fou_countB['sex'] == "M"]
fif_countBC = fif_countB.loc[fif_countB['sex'] == "M"]
#how many black men died each year

# %%
thir_agesB = thir_countBC["age"].mean()
thir_agesW = thir_countWC["age"].mean()
fou_agesB = fou_countBC["age"].mean()
fou_agesW = fou_countWC["age"].mean()
fif_agesB = fif_countBC["age"].mean()
fif_agesW = fif_countWC["age"].mean()
#average age of death for either black men or white men separated by year

# %%
final2013 = [thir_agesB, thir_agesW]
final2014 = [fou_agesB, fou_agesW]
final2015 = [fif_agesB, fif_agesW]
final16 = [2013, 2014, 2015]

# %% [markdown]
# The dataset was created to show the average age of deaths for Black and White Men from 2013 to 2015. Based on the dataframe, one can see that the average age of death in the years 2013, 2014, and 2015 for Black Men was 48.78, 50.67, and 48.59. For White men, the average age was 39.99, 39.54, and 39.79, respectively.

# %%
final_A = [final2013, final2014, final2015]
chart_A = pd.DataFrame(final_A, columns = ['Black Men', 'White Men'], index = [2013, 2014, 2015])
chart_A
# Out:
#       Black Men  White Men
# 2013  48.777778  39.987421
# 2014  50.666667  39.544944
# 2015  48.585366  39.787402

# %% [markdown]
# Using the matplotlib library, a bar graph was created to create a visual aid demonstrating the average age at the time of death due to overdoses in Allegheny County for the years 2013, 2014, and 2015. The bar graph is useful in showing the comparison based on age from overdose deaths for Black and White men. From the graph, we can see that the average age of death for Black men is higher than White men.

# %%
import matplotlib
plotdata = pd.DataFrame(chart_A)
# Plot a bar chart
matplotlib.style.use('g')
plotdata.plot(kind="bar")
plt.title("Average Age at Time of Death from Overdose in Allegheny County")
plt.xlabel("Year")
plt.ylabel("Average Age")
# Out:
# Text(0, 0.5, 'Average Age')

# %% [markdown]
# # SECTION 2

# %% [markdown]
# For this section of the project, we set out to determine the amount of both African American and White men who died in Allegheny County from police encounters between the years of 2013 and 2015. In order to determine the amount from the "Mapping Police Violence" Dataset, we used Pandas data frames as shown below.

# %%
import pandas as pd

# %% [markdown]
# After importing the Pandas library into Python, we went to "MappingPoliceViolence.org" and downloaded the dataset, which includes a list of all individuals in the United States who died during fatal encounters with the police. After downloading this as an Excel file onto a desktop, we saved the file as a CSV file, which allowed us to upload the file into Jupyter Hub. We then opened the file as a Pandas data frame as seen below. Please note that we are using "head" to make data frames shorter and add to the notebook's readability.

# %%
police_data = pd.read_csv("files/MPV.csv")
police_data.head()
# Out:
#               Victim's name Victim's age Victim's gender Victim's race  \
# 0          Willie Roy Allen           57            Male           NaN
# 1               Jeffrey Ely           40            Male         White
# 2               Ivan Cuevas           27            Male      Hispanic
# 3           Anthony Alvarez           22            Male      Hispanic
# 4  Aaron Christopher Pouche           35            Male           NaN
#
#                               URL of image of victim  \
# 0                                                NaN
# 1  https://fatalencounters.org/wp-content/uploads...
# 2  https://fatalencounters.org/wp-content/uploads...
# 3  https://fatalencounters.org/wp-content/uploads...
# 4                                                NaN
#
#   Date of Incident (month/day/year)       Street Address of Incident  \
# 0                         3/31/2021   2626 Lithonia Industrial Blvd.
# 1                         3/31/2021                 247 Sullivan St.
# ...

# %% [markdown]
# This next section was a bit tricky, and with assistance from Dr. Biehl, we used "astype - datetime64," which transferred the data within the column to a data/time field so we could find the incidents within the years from 2013 to 2015. (A helpful way to think about it is "Pandas dtype *datetime64*" = "Python data type = *datetime*"), just as Pandas's dtype "int64" is equal to an "integer" in regular old Python. Same kind of data, just named differently in the library.) After that, we created a query mask to find the incidents between 2013 and 2015, and a second query mask to find the incidents that took place in Allegheny County. Assigning the variable "allegheny_violence" to the combination of both query masks, we found our incidents. Rather than indexing them by numbers from the original dataset, we indexed the resulting data by the victim's name.

# %%
police_data["Date of Incident (month/day/year)"] = police_data["Date of Incident (month/day/year)"].astype("datetime64[ns]")
year_county_mask = (police_data["Date of Incident (month/day/year)"] > "1-1-2013") & (police_data["Date of Incident (month/day/year)"] <= "12-31-2015")
county_query_mask = police_data["County"] == "Allegheny"
allegheny_violence = police_data[county_query_mask & year_county_mask]
allegheny_violence.set_index("Victim's name")
# Out:
#                     Victim's age Victim's gender Victim's race  \
# Victim's name
# Raymone Davis                 21            Male         Black
# Tyrone Harris                 20            Male         Black
# Leslie Sapp III               47            Male         Black
# Adrian Williams               29            Male         Black
# Charles Hull                  56            Male         Black
# Paul Slimick                  26            Male         White
# Jared Brown-Garnham           21            Male         Black
# Shawn Evans                   56            Male         White
# Robert Brooks                 27            Male         White
#
#                                                 URL of image of victim  \
# Victim's name
# Raymone Davis                                                      NaN
# Tyrone Harris        http://www.post-gazette.com/image/2015/06/23/4...
# Leslie Sapp III      https://cbspittsburgh.files.wordpress.com/2015...
# ...

# %% [markdown]
# While not exactly the number we are looking for, let us check-in and see how many individuals were killed in Allegheny County during this time frame during police encounters. (The bottom of the dataset gives us a hint, but let us double-check).

# %%
len(allegheny_violence)
# Out:
# 9

# %% [markdown]
# There is our confirmation - 9 individuals killed. Before performing this data manipulation, we were not sure if we were going to have to factor out the victims by gender or other races, as we are only looking at Black and White men for the project. As one can see, we do not need to do that, as every individual in this new dataset was a Black or White male. Now, in our request to fully answer Question 1, we need to further break down the data sets by race (Black/White), as well as find the median age at the time of death for these two groups of individuals. We are using another query mask to narrow down the dataset to only include victims whose race is "Black."

# %%
b_mask = allegheny_violence["Victim's race"] == "Black"
b_victims = allegheny_violence[b_mask]
b_victims
# Out:
#             Victim's name Victim's age Victim's gender Victim's race  \
# 5885        Raymone Davis           21            Male         Black
# 6400        Tyrone Harris           20            Male         Black
# 6889      Leslie Sapp III           47            Male         Black
# 7643      Adrian Williams           29            Male         Black
# 7882         Charles Hull           56            Male         Black
# 7999  Jared Brown-Garnham           21            Male         Black
#
#                                  URL of image of victim  \
# 5885                                                NaN
# 6400  http://www.post-gazette.com/image/2015/06/23/4...
# 6889  https://cbspittsburgh.files.wordpress.com/2015...
# 7643  https://ionenewpittsburghcourier.files.wordpre...
# 7882  http://www.fatalencounters.org/wp-content/uplo...
# 7999  http://media.masslive.com/breakingnews/photo/2...
#
#      Date of Incident (month/day/year)            Street Address of Incident  \
# ...

# %% [markdown]
# After that, we use the Data Frame function "median" to determine the median age.

# %%
b_victims["Victim's age"].median()
# Out:
# 25.0

# %% [markdown]
# We are now going to repeat the process with White victims to find their median age.

# %%
w_mask = allegheny_violence["Victim's race"] == "White"
w_victims = allegheny_violence[w_mask]
w_victims
# Out:
#       Victim's name Victim's age Victim's gender Victim's race  \
# 7996   Paul Slimick           26            Male         White
# 8248    Shawn Evans           56            Male         White
# 8443  Robert Brooks           27            Male         White
#
#                                  URL of image of victim  \
# 7996        https://www.youtube.com/watch?v=sa5xpCIqZOo
# 8248                                                NaN
# 8443  http://www.post-gazette.com/image/2013/10/17/4...
#
#      Date of Incident (month/day/year) Street Address of Incident  \
# 7996                        2013-12-09             200 E Patty Ln
# 8248                        2013-09-08             4501 Torley St
# 8443                        2013-07-08           302 Thorn Street
#
#              City State  Zipcode  ... Unnamed: 42 Unnamed: 43 Unnamed: 44  \
# 7996  Monroeville    PA  15146.0  ...         NaN         NaN         NaN
# ...

# %%
w_victims["Victim's age"].median()
# Out:
# 27.0

# %% [markdown]
# We found the answers we were looking for – in Allegheny County between 2013 and 2015, the median age for Black men killed in police encounters is 25 and the median age for White men is 27.

# %% [markdown]
# # SECTION 3

# %% [markdown]
# Now, we want to compare the ages of death for these 9 individuals with the median age of death for those in the same municipality.
#
# Again, we start by importing the data into Python using a Pandas library on the median age of death for this period. In particular, the Western Pennsylvania Regional Data Center has tracked the median age at death in Allegheny County between 2011 and 2015 and made that available at "https://data.wprdc.org/dataset/median-age-death".
#
# Fortunately, this already came as a CSV file, and we could then upload it to Jupyter Hub. Reading the file into Python results in the following table showing 131 Allegheny County municipalities and their respective data.

# %%
import pandas as pd
wprdc_data = pd.read_csv("files/munimedianage20112015.csv")
wprdc_data.head()
# Out:
#                Municipality  BLACKdeaths  BLACK MD AGE AT DEATH  WHITEdeaths  \
# 0         Haysville Borough            0                    0.0            5
# 1          Trafford Borough            0                    0.0            5
# 2  Ben Avon Heights Borough            0                    0.0           10
# 3         Glenfield Borough            0                    0.0           16
# 4      Glen Osborne Borough            0                    0.0           19
#
#    WHITE MD AGE AT DEATH  TOTALdeaths  TOTAL MD AGE AT DEATH
# 0                   77.5            5                   77.5
# 1                   80.0            5                   80.0
# 2                   86.7           10                   86.7
# 3                   82.5           16                   82.5
# 4                   78.6           19                   78.6

# %% [markdown]
# Looking through the municipalities here and comparing it to our list of shooting victims, we can see that we will have a few issues merging these datasets. First, there is a pesky misspelling of "Pittsburg" in Shawn Evans' listing. Let us fix that now with a quick "replace" method.

# %%
w_victims_sic = w_victims.replace("Pittsburg","Pittsburgh")
w_victims_sic[w_victims_sic["Victim's name"] == "Shawn Evans"]
# Out:
#      Victim's name Victim's age Victim's gender Victim's race  \
# 8248   Shawn Evans           56            Male         White
#
#      URL of image of victim Date of Incident (month/day/year)  \
# 8248                    NaN                        2013-09-08
#
#      Street Address of Incident        City State  Zipcode  ... Unnamed: 42  \
# 8248             4501 Torley St  Pittsburgh    PA      NaN  ...         NaN
#
#      Unnamed: 43 Unnamed: 44 Unnamed: 45 Unnamed: 46 Unnamed: 47 Unnamed: 48  \
# 8248         NaN         NaN         NaN         NaN         NaN         NaN
#
#      Unnamed: 49 Unnamed: 50 Unnamed: 51
# 8248         NaN         NaN         NaN
#
# [1 rows x 52 columns]

# %% [markdown]
# Another issue is that the WPRDC data does not include a listing for the Knoxville neighborhood. However, the WPRDC data does include Mount Oliver, which is adjacent to Knoxville so we will substitute Knoxville into the WPRDC dataframe to get the median age of death for the adjacent neighborhood.

# %%
wprdc_sub = wprdc_data.replace("Mount Oliver Borough","Knoxville")
wprdc_sub[wprdc_sub.Municipality == "Knoxville"]
# Out:
#     Municipality  BLACKdeaths  BLACK MD AGE AT DEATH  WHITEdeaths  \
# 113    Knoxville           37                   52.5          151
#
#      WHITE MD AGE AT DEATH  TOTALdeaths  TOTAL MD AGE AT DEATH
# 113                   71.7          195                   67.8

# %% [markdown]
# The last, more serious issue, is that the "City" designation in our table does not include Township or Borough identifiers that the WPRDC data does. We drop those designations and merge each table. After merging the data, we want to highlight the important information. So, we create a new column right after "Victim's Age" to input the median age at death in our dataset, and we create another new column to show the median age at death in their neighborhood. This will help us make a graphic later on.

# %%
wprdc_sub["City"] = wprdc_sub["Municipality"].str.replace("\sBorough|\sTownship","")
wprdc_sub
# Out:
#                  Municipality  BLACKdeaths  BLACK MD AGE AT DEATH  \
# 0           Haysville Borough            0                    0.0
# 1            Trafford Borough            0                    0.0
# 2    Ben Avon Heights Borough            0                    0.0
# 3           Glenfield Borough            0                    0.0
# 4        Glen Osborne Borough            0                    0.0
# ..                        ...          ...                    ...
# 125                  Clairton          149                   70.9
# 126                McKeesport          344                   65.0
# 127       Wilkinsburg Borough          625                   70.9
# 128       Penn Hills Township          684                   72.0
# 129                Pittsburgh         4255                   71.8
#
#      WHITEdeaths  WHITE MD AGE AT DEATH  TOTALdeaths  TOTAL MD AGE AT DEATH  \
# 0              5                   77.5            5                   77.5
# ...

# %%
wprdcxw_victims = w_victims_sic.merge(wprdc_sub)
wprdcxw_victims.insert(2,"Median Age at Death in Neighborhood",wprdcxw_victims["WHITE MD AGE AT DEATH"])
wprdcxw_victims.insert(3,"Median Age at Death",w_victims["Victim's age"].median())
wprdcxw_victims
# Out:
#    Victim's name Victim's age  Median Age at Death in Neighborhood  \
# 0   Paul Slimick           26                                 84.7
# 1    Shawn Evans           56                                 79.9
# 2  Robert Brooks           27                                 84.1
#
#    Median Age at Death Victim's gender Victim's race  \
# 0                 27.0            Male         White
# 1                 27.0            Male         White
# 2                 27.0            Male         White
#
#                               URL of image of victim  \
# 0        https://www.youtube.com/watch?v=sa5xpCIqZOo
# 1                                                NaN
# 2  http://www.post-gazette.com/image/2013/10/17/4...
#
#   Date of Incident (month/day/year) Street Address of Incident         City  \
# 0                        2013-12-09             200 E Patty Ln  Monroeville
# 1                        2013-09-08             4501 Torley St   Pittsburgh
# ...

# %%
wprdcxb_victims = b_victims.merge(wprdc_sub)
wprdcxb_victims.insert(2,"Median Age at Death in Neighborhood",wprdcxb_victims["BLACK MD AGE AT DEATH"])
wprdcxb_victims.insert(3,"Median Age at Death",b_victims["Victim's age"].median())
wprdcxb_victims
# Out:
#          Victim's name Victim's age  Median Age at Death in Neighborhood  \
# 0        Raymone Davis           21                                 71.8
# 1        Tyrone Harris           20                                 71.8
# 2      Leslie Sapp III           47                                 52.5
# 3      Adrian Williams           29                                 70.9
# 4         Charles Hull           56                                 72.0
# 5  Jared Brown-Garnham           21                                 69.0
#
#    Median Age at Death Victim's gender Victim's race  \
# 0                 25.0            Male         Black
# 1                 25.0            Male         Black
# 2                 25.0            Male         Black
# 3                 25.0            Male         Black
# 4                 25.0            Male         Black
# 5                 25.0            Male         Black
#
#                               URL of image of victim  \
# ...

# %% [markdown]
# Now, we can get an answer to which demographic group (White or Black men) die from overdoses or police encounters closest to their median age. Since our data cannot give a direct answer to median age at death in Allegheny County, we will take the average of the medians from the Western Pennsylvania Regional Data Center data. It seems that some municipalities did not report the ages of death for Black individuals, so we will keep those out of the average.

# %%
bvictim_pe_median = wprdcxb_victims["Victim's age"].median()
ballegheny_avg = round(wprdc_data["BLACK MD AGE AT DEATH"][59:129].mean(),2)
difference1 = round(ballegheny_avg - bvictim_pe_median,2)
print("The median age for black males to die from a police encounter between 2013 and 2015 was: " + str(bvictim_pe_median) + ", which was " + str(difference1) + " years less than the average age at death for black people in Allegheny County of " + str(ballegheny_avg) + " years.")
# Out:
# The median age for black males to die from a police encounter between 2013 and 2015 was: 25.0, which was 43.22 years less than the average age at death for black people in Allegheny County of 68.22 years.

# %%
wvictim_pe_median = wprdcxw_victims["Victim's age"].median()
wallegheny_avg = wprdc_data["WHITE MD AGE AT DEATH"].mean()
difference2 = round(wallegheny_avg - wvictim_pe_median, 2)
print("The median age for white males to die from a police encounter between 2013 and 2015 was: " + str(wvictim_pe_median) + ", which was " + str(difference2) + " years less than the average age at death for white people in Allegheny County of " + str(wallegheny_avg) + " years.")
# Out:
# The median age for white males to die from a police encounter between 2013 and 2015 was: 27.0, which was 53.07 years less than the average age at death for white people in Allegheny County of 80.07 years.

# %%
b_od_median = raceMB['age'].median()
difference3 = round(ballegheny_avg - b_od_median,2)
print("The median age for black males to die from an overdose between 2013 and 2015 was: " + str(b_od_median) + ", which was " + str(difference3) + " years less than the average age at death for black people in Allegheny County of " + str(ballegheny_avg) + " years.")
# Out:
# The median age for black males to die from an overdose between 2013 and 2015 was: 51.0, which was 17.22 years less than the average age at death for black people in Allegheny County of 68.22 years.

# %%
w_od_median = raceMW['age'].median()
difference4 = round(wallegheny_avg - w_od_median,2)
print("The median age for white males to die from an overdose between 2013 and 2015 was: " + str(w_od_median) + ", which was " + str(difference4) + " years less than the average age at death for black people in Allegheny County of " + str(wallegheny_avg) + " years.")
# Out:
# The median age for white males to die from an overdose between 2013 and 2015 was: 38.0, which was 42.07 years less than the average age at death for black people in Allegheny County of 80.07 years.

# %% [markdown]
# This shows that Black men dying of overdoses is the closest demographic to the average in Allegheny County, losing over 17 years compared to their counterparts in the community.
#
# Next, we want to break down the median age of deaths, split by race, for both police encounters and overdose deaths in each year. For this, we need matplotlib. But first, we need the median ages split by year. This is easiest for White victims of police encounters since they all occurred in 2013, but for the rest, we need to use a variation on our earlier masks.

# %%
wprdcxb_victims["Date of Incident (month/day/year)"] = wprdcxb_victims["Date of Incident (month/day/year)"].astype("datetime64[ns]")
black_encounter_2013 = (wprdcxb_victims["Date of Incident (month/day/year)"] > "1-1-2013") & (wprdcxb_victims["Date of Incident (month/day/year)"] <= "12-31-2013")
medianpe_2013 = wprdcxb_victims[black_encounter_2013]
black_encounter_2014 = (wprdcxb_victims["Date of Incident (month/day/year)"] > "1-1-2014") & (wprdcxb_victims["Date of Incident (month/day/year)"] <= "12-31-2014")
medianpe_2014 = wprdcxb_victims[black_encounter_2014]
black_encounter_2015 = (wprdcxb_victims["Date of Incident (month/day/year)"] > "1-1-2015") & (wprdcxb_victims["Date of Incident (month/day/year)"] <= "12-31-2015")
medianpe_2015 = wprdcxb_victims[black_encounter_2015]

# %% [markdown]
# And we do the same for overdose deaths, using the "case_year" column.

# %%
white_overdose_2013 = (raceMW["case_year"] == 2013)
wmedianod_2013 = raceMW[white_overdose_2013]
white_overdose_2014 = (raceMW["case_year"] == 2014)
wmedianod_2014 = raceMW[white_overdose_2014]
white_overdose_2015 = (raceMW["case_year"] == 2015)
wmedianod_2015 = raceMW[white_overdose_2015]

black_overdose_2013 = (raceMB["case_year"] == 2013)
bmedianod_2013 = raceMB[black_overdose_2013]
black_overdose_2014 = (raceMB["case_year"] == 2014)
bmedianod_2014 = raceMB[black_overdose_2014]
black_overdose_2015 = (raceMB["case_year"] == 2015)
bmedianod_2015 = raceMB[black_overdose_2015]

# %% [markdown]
# Now that we split our data by year, we can calculate the median directly into our dataset and make a nice, neat graph!

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['2013', '2014', '2015']
black_encounter = [medianpe_2013["Victim's age"].median(), medianpe_2014["Victim's age"].median(), medianpe_2015["Victim's age"].median()]
white_encounter = [wprdcxw_victims["Victim's age"].median(), 0, 0]
black_overdose = [bmedianod_2013["age"].median(), bmedianod_2014["age"].median(), bmedianod_2015["age"].median()]
white_overdose = [wmedianod_2013["age"].median(), wmedianod_2014["age"].median(), wmedianod_2015["age"].median()]

x = np.arange(len(labels))
width = 0.3

fig, ax = plt.subplots()
rects1 = ax.bar(x - 1.5*width, white_encounter, width, label='White Encounter')
rects2 = ax.bar(x - width/2, black_encounter, width, label='Black Encounter')
rects3 = ax.bar(x + width/2, white_overdose, width, label='White Overdose')
rects4 = ax.bar(x + 1.5*width, black_overdose, width, label='Black Overdose')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Median Age at Death')
ax.set_title('Comparison of Median Ages: Police Encounters / Overdoses')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc=2, fontsize='small')


fig.tight_layout()

plt.show()

# %%
fig, ax = plt.subplots()

x = np.linspace(0,2,3)
black_encounter = [medianpe_2013["Victim's age"].median(), medianpe_2014["Victim's age"].median(), medianpe_2015["Victim's age"].median()]
line1 = ax.plot(x, black_encounter, label='Black Encounter')

x2 = np.linspace(0,2,3)
white_encounter = [wprdcxw_victims["Victim's age"].median(), 0, 0]
line1 = ax.plot(x2, white_encounter, label='White Encounter')

x3 = np.linspace(0,2,3)
black_overdose = [bmedianod_2013["age"].median(), bmedianod_2014["age"].median(), bmedianod_2015["age"].median()]
line1 = ax.plot(x3, black_overdose, label='Black OD')

x4 = np.linspace(0,2,3)
white_overdose = [wmedianod_2013["age"].median(), wmedianod_2014["age"].median(), wmedianod_2015["age"].median()]
line1 = ax.plot(x4, white_overdose, label='White OD')
labels = ['2013', '2014', '2015']
plt.title('Comparison of Median Ages: Police Encounters / Overdoses')
labels = ["2013", "2014", "2015"]
plt.xticks(np.arange(3), labels)
plt.ylabel("Median Age at Death")
ax.legend()
plt.show()

# %% [markdown]
# As we can see, while the median age of police encounter deaths for both genders is generally less than those for overdoses, there is a lot more variability in that data since we are dealing with less than 5 individuals in each category per year.
#
# For the next chart, we look at the difference between deaths, split by race, between overdose deaths and police encounter deaths to examine the scope of each problem from 2013 to 2015.

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['Black Encounter', 'White Encounter', 'Black OD', 'White OD']
deaths = [len(b_victims["Victim's age"]), len(w_victims["Victim's age"]), len(raceMB['age']), len(raceMW['age'])]

x = np.arange(len(labels))
width = 0.35


fig, ax = plt.subplots()
ax.bar(labels, deaths, color = "black")
ax.set_title('Comparison of Total Deaths: Police Encounters / Overdoses')
ax.set_ylabel('Deaths (2013-2015)')
ax.set_yscale('log')
ax.set_xticks(x)
ax.set_xticklabels(labels)

fig.tight_layout()


plt.show()

# %% [markdown]
# We had to use a logarithmic scale on the y-axis here because otherwise the "encounter" bars were barely visible lines. Still, as we can see, overdose deaths far outstripped fatalities from police encounters. While White men were more likely to overdose between 2013 and 2015, Black men were more likely to die at the hands of police.

# %% [markdown]
# ## Results
#
# **1. How many individuals died in Allegheny County between 2013 and 2015 from drug overdose? How many individuals died in this same county and time frame from police encounters? What is the median age of death for each of these groups of people?**
#
# In Allegheny County between the years 2013-2015, 997 total individuals died from accidental overdoses. The following number of deaths occurred per year:
# - 269 deaths in 2013
# - 306 death in 2014
# - 422 death in 2015
#
# In Allegheny County, during the years ranging from 2013 to 2015, the number of accidental overdoses was 591 for White men died and for Black men, 98 died of accidental overdose.
#
# Between 2013 and 2015, the average age of Black men who died from accidental overdose was 49.28 and the average age of White men who died from accidental overdose was 39.77.
#
# In Allegheny County between the years 2013-2015, 9 total individuals died from fatal police encounters.
#
# Between the years of 2013 and 2015, the average age of a person dying from accidental overdose in Allegheny County was 41.39.
# - 234 White people died in 2013, 159 being men.
# - 306 White people died in 2014, 178 being men.
# - 422 White people died in 2015, 254 being men.
# - 34 Black people died in 2013, 27 being men.
# - 44 Black people died in 2014, 30 being men.
# - 57 Black people died in 2015, 41 being men.
#
# **2. What was the overall median age at death of both white and black men in Allegheny County between 2013 and 2015, regardless of cause of death?**
#
# In Allegheny County between 2013 and 2015, the average age for each year and race is as follows:
# - 2013: Black men - 48.78, White men - 39.99
# - 2014: Black men - 50.67, White men - 39.54
# - 2015: Black men - 48.59, White men - 39.79
#
# **3. Between 2013 and 2015, what of the four demographic groups established (White men/Black men dying from police encounter/drug overdose) is closest to the median age at time of death in Allegheny County? What are the margins for each group?**
#
# The median age for Black males to die from a police encounter between 2013 and 2015 was: 25.0, which was 43.22 years less than the average age at death for black people in Allegheny County of 68.22 years
#
# The median age for White males to die from a police encounter between 2013 and 2015 was: 27.0, which was 53.07 years less than the average age at death for white people in Allegheny County of 80.07 years.
#
# The median age for Black males to die from an overdose between 2013 and 2015 was: 51.0, which was 17.22 years less than the average age at death for black people in Allegheny County of 68.22 years.
#
# The median age for White males to die from an overdose between 2013 and 2015 was: 38.0, which was 42.07 years less than the average age at death for black people in Allegheny County of 80.07 years.
#
# Ultimately, the data indicates that Black men dying of overdoses is the closest demographic to the average in Allegheny County, losing over 17 years compared to their counterparts in the community.

# %% [markdown]
# ## Insights/Conclusion
#
# White men were more likely to overdose between 2013 and 2015 whereas Black men were more likely to die at the hands of police.
#
# It is important to recognize that the data comprised in the datasets may be incomplete or incorrect.
#
# "While there are undoubtedly police killings that are not included in our database (namely, those that go unreported by the media), these estimates suggest that our database captures 92% of the total number of police killings that have occurred since 2013. We hope these data will be used to provide greater transparency and accountability for police departments as part of the ongoing campaign to end police violence in our communities."
#
# Policy recommendations on the national level to address issues of police brutality include input from social justice organizations such as Say Her Name and Black Lives Matter. The ideas put forth by these organizations are important to address and include as these groups formed in response to police brutality cases as these individuals experienced firsthand police terror. Other recommendations include measures proposed by David Harris, a Professor of Law at the University of Pittsburgh.
#
# Rates of police brutality have not been curtailed by the use of training, unbiased training, and technology such as cameras.  Currently, police departments have enacted and introduced new methods to record interactions between police officers and individuals. Police have included dash cams in the patrol vehicle and other police departments have started requiring their police officers to wear a camera on their person so that they can properly document all the interactions that take place outside of the patrol car. However, some officers will turn off their cameras to hide their actions or will continue to misbehave while such cameras are on. More needs to be done.
#
# An institutional and systemic problem exists. Enacting basic reforms such as police training, bias training and cameras are not enough because the foundation of the policing system was based on the subjugation of African Americans as slave patrols were the first modern police force.  Furthermore, police officers have served for the most part as enactors and protectors of white supremacy and white citizens.  Today, the visibility and recognition of police brutality relies on civilians or individuals themselves utilizing cellphones to record officers or such cases will have never been seen. With the use of social media sites, television news, and online sites, technology plays a pivotal role in the actions that are displayed by police officials.
#
# Inequality exists in the criminal justice system. The criminal justice system and laws such as cash bail are designed and enacted in a manner that reinforces hierarchy and privilege. One can simply say get rid of cash bail but the roots of inequality pervading the system are much deeper. Both policing and the criminal justice system are operating as they were designed reinforcing issues of race, class, and gender. The criminal justice system needs to be radically changed.

# %% [markdown]
# ## <center>Bibliography<center>

# %% [markdown]
# African American Policy Forum. #Say Her Name Demands & Policies. https://aapf.org/shndemands.
#
# African American Policy Forum. #Say Her Name: Resisting Police Brutality Against Black Women. https://aapf.org/sayhernamereport.
#
# Alexander, Michelle. *The New Jim Crow: Mass Incarceration in the Age of Colorblindness*. New York: The New Press, 2010.
#
# Barlow, David E. and Melissa Hickman Barlow. *Police in a Multicultural Society: An American Story*. Waveland Press, 2000.
#
# Bodnar, John E., Roger D. Simon, and Michael P. Weber. *Lives of Their Own: Blacks, Italians, and Poles in Pittsburgh, 1900-1960*. Urbana: University of Illinois Press, 1983.
#
# Collins, James. “Taking the Lead: Dorothy Williams, NAACP Youth Councils, and Civil Rights Protests in Pittsburgh, 1961-1964.” *The Journal of African American History* 88, no. 2 (2003): 126-137, https://www.jstor.org/stable/3559061.
#
# Elsinore-Bennu Think Tank for Restorative Justice. http://ebthinktank.org/about-2/.
#
# Finley, Cheryl, Laurence Admiral Glasco, and Joe William Trotter. *Teenie Harris, Photographer: Image, Memory, History*. University of Pittsburgh Press, 2011.
#
# Harris, David A. *A City Divided: Race, Fear and the Law in Police Confrontations*. Anthem Press, 2020.
#
# Tate, Julie, Jennifer Jenkins and Steven Rich. “Fatal Force: Police Shootings Database.” *The Washington Post*. Accessed March 14, 2021. www.washingtonpost.com/graphics/investigations/police-shootings-database/.
#
# Tonry, Michael. “Racial Politics, Racial Disparities, and the War on Crime.” *Crime & Delinquency* 40, no. 4 (1994): 475-494.
#
# Trotter, Joe and Jared Day. *Race and Renaissance: African Americans in Pittsburgh Since World War II*. University of Pittsburgh Press, 2010.
